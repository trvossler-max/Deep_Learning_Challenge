# %% [markdown]
# <a href="https://colab.research.google.com/github/trvossler-max/Deep_Learning_Challenge/blob/main/Starter_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Preprocessing

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("/charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME  ... ASK_AMT IS_SUCCESSFUL
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB  ...    5000             1
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR  ...  108590             1
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS  ...    5000             0
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION  ...    6692             1
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT  ...  142590             1
#
# [5 rows x 12 columns]

# %%
# Drop the non-beneficial ID columns, 'EIN' and 'NAME'.
application_df = application_df.drop(['EIN', 'NAME'], axis=1)

application_df
# Out:
#       APPLICATION_TYPE       AFFILIATION  ...   ASK_AMT IS_SUCCESSFUL
# 0                  T10       Independent  ...      5000             1
# 1                   T3       Independent  ...    108590             1
# 2                   T5  CompanySponsored  ...      5000             0
# 3                   T3  CompanySponsored  ...      6692             1
# 4                   T3       Independent  ...    142590             1
# ...                ...               ...  ...       ...           ...
# 34294               T4       Independent  ...      5000             0
# 34295               T4  CompanySponsored  ...      5000             0
# 34296               T3  CompanySponsored  ...      5000             0
# 34297               T5       Independent  ...      5000             1
# 34298               T3       Independent  ...  36500179             0
#
# [34299 rows x 10 columns]

# %%
# Determine the number of unique values in each column.
application_df.nunique(axis=0)
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T14        3
# T25        3
# T15        2
# T29        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace = ['T9', 'T13', 'T12', 'T2', 'T25', 'T14', 'T15', 'T29', 'T17']

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
#          ...
# C2190        1
# C1283        1
# C1570        1
# C1248        1
# C3700        1
# Name: CLASSIFICATION, Length: 71, dtype: int64

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
application_df['CLASSIFICATION'].value_counts().loc[lambda x : x>1]
#application_df['CLASSIFICATION'].value_counts()[application_df['CLASSIFICATION'].value_counts()> 1]
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# C7000      777
# C1700      287
# C4000      194
# C5000      116
# C1270      114
# C2700      104
# C2800       95
# C7100       75
# C1300       58
# C1280       50
# C1230       36
# C1400       34
# C7200       32
# C2300       32
# C1240       30
# C8000       20
# C7120       18
# C1500       16
# C6000       15
# C1800       15
# C1250       14
# C8200       11
# C1278       10
# C1238       10
# C1235        9
# C1237        9
# C7210        7
# C1720        6
# C2400        6
# C4100        6
# C1257        5
# C1600        5
# C0           3
# C1260        3
# C2710        3
# C1234        2
# C3200        2
# C1256        2
# C1267        2
# C1246        2
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications = application_df['CLASSIFICATION'].value_counts().loc[lambda x : x < 778]
classifications_to_replace = dict(classifications)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")
    
# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2261
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
final_application = pd.get_dummies(application_df)

final_application
# Out:
#        STATUS   ASK_AMT  ...  SPECIAL_CONSIDERATIONS_N  SPECIAL_CONSIDERATIONS_Y
# 0           1      5000  ...                         1                         0
# 1           1    108590  ...                         1                         0
# 2           1      5000  ...                         1                         0
# 3           1      6692  ...                         1                         0
# 4           1    142590  ...                         1                         0
# ...       ...       ...  ...                       ...                       ...
# 34294       1      5000  ...                         1                         0
# 34295       1      5000  ...                         1                         0
# 34296       1      5000  ...                         1                         0
# 34297       1      5000  ...                         1                         0
# 34298       1  36500179  ...                         1                         0
#
# ...

# %%
# Split our preprocessed data into our features and target arrays
X = final_application.copy()
y = final_application["IS_SUCCESSFUL"].copy()
X = X.drop("IS_SUCCESSFUL", axis=1)

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=13)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=21, activation="relu", input_dim=43))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=21, activation="relu"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense (Dense)                (None, 21)                924
# _________________________________________________________________
# dense_1 (Dense)              (None, 21)                462
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 22
# ...
# Total params: 1,408
# Trainable params: 1,408
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled, y_train, epochs=90)
# Out:
# Epoch 1/90
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5889 - accuracy: 0.7078
# Epoch 2/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5579 - accuracy: 0.7276
# Epoch 3/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5547 - accuracy: 0.7283
# Epoch 4/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5524 - accuracy: 0.7297
# Epoch 5/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5514 - accuracy: 0.7308
# Epoch 6/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5501 - accuracy: 0.7303
# Epoch 7/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5496 - accuracy: 0.7320
# Epoch 8/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5485 - accuracy: 0.7319
# Epoch 9/90
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5488 - accuracy: 0.7318
# Epoch 10/90
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5526 - accuracy: 0.7264
# Loss: 0.552635133266449, Accuracy: 0.7264139652252197

# %%
# Export our model to HDF5 file
nn.save('nn_model1')
# Out:
# INFO:tensorflow:Assets written to: nn_model1/assets

# %% [markdown]
# **Optimization 1:** Changing activation and epoch parameters and reducing the neurons in the hidden layers. No change to features.

# %%
nn_model2 = tf.keras.models.Sequential()

# First hidden layer
nn_model2.add(tf.keras.layers.Dense(units=8, activation="sigmoid", input_dim=43))

# Second hidden layer
nn_model2.add(tf.keras.layers.Dense(units=6, activation="relu"))

# Output layer
nn_model2.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model2.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_7 (Dense)              (None, 8)                 352
# _________________________________________________________________
# dense_8 (Dense)              (None, 6)                 54
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 7
# ...
# Total params: 413
# Trainable params: 413
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model2.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_model2.fit(X_train_scaled, y_train, epochs=50)
# Out:
# Epoch 1/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5430 - accuracy: 0.7365
# Epoch 2/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7367
# Epoch 3/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7357
# Epoch 4/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7356
# Epoch 5/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5429 - accuracy: 0.7365
# Epoch 6/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5427 - accuracy: 0.7359
# Epoch 7/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7371
# Epoch 8/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5428 - accuracy: 0.7366
# Epoch 9/50
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5426 - accuracy: 0.7362
# Epoch 10/50
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model2.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5511 - accuracy: 0.7303
# Loss: 0.5511220097541809, Accuracy: 0.7302623987197876

# %%
# Export our model to HDF5 file
nn_model2.save('nn_model2')
# Out:
# INFO:tensorflow:Assets written to: nn_model2/assets

# %% [markdown]
# **Optimization 2:** Adding another hidden layer and changing the number of neural nodes and output activation function to the model and setting epochs to 75. No change to features

# %%
nn_model3 = tf.keras.models.Sequential()

# First hidden layer
nn_model3.add(tf.keras.layers.Dense(units=20, activation="sigmoid", input_dim=43))

# Second hidden layer
nn_model3.add(tf.keras.layers.Dense(units=16, activation="relu"))

# Third hidden layer
nn_model3.add(tf.keras.layers.Dense(units=8, activation="relu"))

# Output layer
nn_model3.add(tf.keras.layers.Dense(units=1, activation="tanh"))

# Check the structure of the model
nn_model3.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_3 (Dense)              (None, 20)                880
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                336
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 9
# ...
# Total params: 1,361
# Trainable params: 1,361
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_model3.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_model3.fit(X_train_scaled, y_train, epochs=75)
# Out:
# Epoch 1/75
# 804/804 [==============================] - 2s 2ms/step - loss: 1.7161 - accuracy: 0.5774
# Epoch 2/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.6155 - accuracy: 0.6925
# Epoch 3/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5839 - accuracy: 0.7102
# Epoch 4/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5757 - accuracy: 0.7156
# Epoch 5/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5709 - accuracy: 0.7191
# Epoch 6/75
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5688 - accuracy: 0.7226
# Epoch 7/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5666 - accuracy: 0.7257
# Epoch 8/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5650 - accuracy: 0.7252
# Epoch 9/75
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5653 - accuracy: 0.7245
# Epoch 10/75
# ...

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_model3.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5544 - accuracy: 0.7286
# Loss: 0.5543981194496155, Accuracy: 0.7286297082901001

# %%
# Export our model to HDF5 file
nn_model3.save('nn_model3')
# Out:
# INFO:tensorflow:Assets written to: nn_model3/assets
